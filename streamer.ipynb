# %% [markdown]
# <a href="https://colab.research.google.com/github/barton-muller/mriseg/blob/main/streamer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/barton-muller/mriseg.git
# Out:
# Cloning into 'mriseg'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 20 (delta 2), reused 19 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (20/20), 23.54 KiB | 370.00 KiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# prompt: add mriseg to path

import sys
sys.path.append('/content/mriseg')

# %%
import BRATZcore
# Out:
# No GPU detected—falling back to CPU

# %%
! pip install streamlit -q
# !wget -q -O - ipv4.icanhazip.com
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 78.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 102.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.2 MB/s eta 0:00:00
# 34.125.58.188

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !streamlit run mriseg/viewer.py & npx localtunnel --port 8501
# Out:
# ...
#
# ⠙⠹⠸⠼⠴⠦
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.125.58.188:8501
#
# ⠧your url is: https://upset-planes-walk.loca.lt
# No GPU detected—falling back to CPU
# Found 100 training patients, 50 test patients.
# Found 100 training patients, 50 test patients.
# ────────────────────────── Traceback (most recent call last) ───────────────────────────
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/exec_code.py:
#   121 in exec_func_with_error_handling
#
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner
#   .py:645 in code_to_exec
#
#   /content/mriseg/viewer.py:128 in <module>
#
#     125 # Locate the folder for the selected patient
#     126 folder = pd.patient_file_loc(patient_id)
#     127 # List all MRI frame files (exclude predicted ones and hidden files)
# ...
